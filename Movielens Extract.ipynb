# %%
# Import dependencies
import json
import pandas as pd
import numpy as np

# %%
# define the directory location of the data file
file_dir = 'D://Courses/Data Analytics Boot Camp/Modules/Module_8-ETL/Movies-ETL/Data/'

# %%
# Load the csv files into Pandas DFs
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
# Check number of rows and columns for the DFs
kaggle_metadata.shape
# Out:
# (45466, 24)

# %%
ratings.shape
# Out:
# (26024289, 4)

# %%
# Inspect the DFs using head(), tail(), and sample() methods
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
kaggle_metadata.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
# get 5 random rows from the DF
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 35522  False                   NaN      0
# 11204  False                   NaN      0
# 11983  False                   NaN      0
# 13447  False                   NaN      0
# 17634  False                   NaN      0
#
#                                                   genres homepage     id  \
# 35522                      [{'id': 18, 'name': 'Drama'}]      NaN  73976
# 11204  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN  51601
# 11983                     [{'id': 27, 'name': 'Horror'}]      NaN  40060
# 13447  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...      NaN  43034
# 17634                      [{'id': 18, 'name': 'Drama'}]      NaN  88271
#
#          imdb_id original_language            original_title  \
# 35522  tt1735853                pt             Como Esquecer
# 11204  tt0029511                en               San Quentin
# 11983  tt0077904                en               The Manitou
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 10346120  106832    33166     4.5  1129323824
# 6797736    70179     6636     4.0  1104183940
# 24429130  253810     2048     3.0   987730143
# 3981828    41380     2916     3.0   954547032
# 7741158    79831     1298     3.0   940675534
